# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielramirez2109/proyectomatesegundo/blob/main/figures/graficas%20y%20datos%20finales/mapacoro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('base_final_combinada.csv')


df['desc_ent'] = df['desc_ent'].str.strip()


estados = gpd.read_file('mexico_states.geojson')


estados['name'] = estados['name'].str.strip()


choropleth = estados.merge(df[['desc_ent', 'ing_cor']],
                           left_on='name', right_on='desc_ent',
                           how='left')

# %%
fig.savefig('mapa_coropletico.png', dpi=300, bbox_inches='tight')

from google.colab import files
files.download('mapa_coropletico.png')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 12))

choropleth.plot(column='ing_cor',
                cmap='OrRd',         # paleta de rojo
                linewidth=0.5,
                edgecolor='gray',
                legend=True,
                legend_kwds={
                  'label': "Ingreso por Hogar Promedio (MXN)",
                  'orientation': "horizontal"
                },
                ax=ax)

ax.set_title(
    "Mapa Coroplético: Ingreso Promedio por Hogar\npor Entidad Federativa",
    fontsize=16, pad=20
)
ax.axis('off')  # quita ejes

plt.show()
